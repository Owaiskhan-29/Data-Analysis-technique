# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Univarite

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize = (10,9))
sns.distplot(df['total_bill'], hist = False, rug = True)
# Out:
# C:\Users\Harish Sriramoju\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Harish Sriramoju\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
fig, axes = plt.subplots(1,2)

# %%
# count plot
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot('day', data = df)
# Out:
# C:\Users\Harish Sriramoju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
#plt.figure(figsize = (10,9))
sns.regplot(x= 'total_bill', y = 'tip', data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# %matplotlib inline
plt.figure(figsize = (10,9))
sns.jointplot(x= 'total_bill', y = 'tip', data = df, kind = 'hex')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x = 'time', y = 'total_bill', data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(x = 'time', y = 'total_bill', data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
facet = sns.FacetGrid(df, col = 'day', hue = 'sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet.add_legend()

# %%
sns.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-aa7ead4d0155> in <module>
# ----> 1 sns.heatmap(df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
#     537                           yticklabels, mask)
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     153
#     154         # Determine good default values for the colormapping
# --> 155         self._determine_cmap_params(plot_data, vmin, vmax,
#     156                                     cmap, center, robust)
#     157
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     187
#     188         # plot_data is a np.ma.array instance
# --> 189         calc_data = plot_data.astype(float).filled(np.nan)
#     190         if vmin is None:
#     191             if robust:
#
# ValueError: could not convert string to float: 'Female'

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df['total_bill'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['total_bill'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot.scatter(x = 'total_bill', y = 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.hexbin(x = 'total_bill', y = 'tip', gridsize = 10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
import findspark
findspark.init()
findspark.find()
import pyspark
findspark.find()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-00438825581b> in <module>
# ----> 1 import findspark
#       2 findspark.init()
#       3 findspark.find()
#       4 import pyspark
#       5 findspark.find()
#
# ModuleNotFoundError: No module named 'findspark'

# %%
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
conf = pyspark.SparkConf().setAppName('appName').setMaster('local')
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession(sc)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-2d382ed9b0d1> in <module>
#       3 from pyspark.sql import SparkSession
#       4 conf = pyspark.SparkConf().setAppName('appName').setMaster('local')
# ----> 5 sc = pyspark.SparkContext(conf=conf)
#       6 spark = SparkSession(sc)
#
# ~\anaconda3\lib\site-packages\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     131                 " is not allowed as it is a security risk.")
#     132
# --> 133         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     134         try:
#     135             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# ~\anaconda3\lib\site-packages\pyspark\context.py in _ensure_initialized(cls, instance, gateway, conf)
#     323         with SparkContext._lock:
#     324             if not SparkContext._gateway:
# --> 325                 SparkContext._gateway = gateway or launch_gateway(conf)
#     326                 SparkContext._jvm = SparkContext._gateway.jvm
#     327
#
# ~\anaconda3\lib\site-packages\pyspark\java_gateway.py in launch_gateway(conf, popen_kwargs)
#     103
#     104             if not os.path.isfile(conn_info_file):
# --> 105                 raise Exception("Java gateway process exited before sending its port number")
#     106
#     107             with open(conn_info_file, "rb") as info:
#
# Exception: Java gateway process exited before sending its port number

# %%
import os
#print(os.environ['SPARK_HOME'])
#print(os.environ['JAVA_HOME'])
print(os.environ['PATH'])
# Out:
# C:\Users\Harish Sriramoju\anaconda3;C:\Users\Harish Sriramoju\anaconda3\Library\mingw-w64\bin;C:\Users\Harish Sriramoju\anaconda3\Library\usr\bin;C:\Users\Harish Sriramoju\anaconda3\Library\bin;C:\Users\Harish Sriramoju\anaconda3\Scripts;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files\Graphviz 2.44.1\bin;C:\Program Files\poppler-0.68.0\bin\;C:\Program Files\poppler-20.11.0\bin\poppler.dll;C:\Program Files\MySQL\MySQL Shell 8.0\bin\;C:\Users\Harish Sriramoju\anaconda3;C:\Users\Harish Sriramoju\anaconda3\Library\mingw-w64\bin;C:\Users\Harish Sriramoju\anaconda3\Library\usr\bin;C:\Users\Harish Sriramoju\anaconda3\Library\bin;C:\Users\Harish Sriramoju\anaconda3\Scripts;C:\Users\Harish Sriramoju\AppData\Local\Microsoft\WindowsApps;C:\Users\Harish Sriramoju\AppData\Local\GitHubDesktop\bin
