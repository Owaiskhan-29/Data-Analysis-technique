# %%
import pandas as pd

df = pd.read_csv("https://s3.amazonaws.com/baywheels-data/2017-fordgobike-tripdata.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-1ce737379ca7> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("https://s3.amazonaws.com/baywheels-data/2017-fordgobike-tripdata.csv")
#
# ...
