# %%
import pandas as pd


data = {
    "GR Number": [25123, 40653, 40486, 42657, 24548, 32820, 45824, 25810, 40497, 40941, 25086, 42181, 30114, 25107, 37161,
                  34173, 37307, 40667, 30962, 41859, 38720, 22481, 34033, 46709, 43706, 44003, 30524, 39668, 29420, 24923,
                  36697, 22368, 53030, 26760, 55118, 22607, 53917, 40509, 25899, 39133, 38273, 47985, 43201, 22701, 36944, 
                  53926, 48103, 42850, 38400, 34087, 42474, 39733, 41636, 46723, 47535, 36946, 35548, 31500, 30523, 30872,
                  48563, 41371, 27073, 42182, 45001, 54947, 47641, 47854, 30751, 37940, 50861, 33637, 34689, 39646, 54790, 
                  38058, 30553, 27155, 37237, 43835, 43244, 48961, 39995, 38851, 55241, 34679, 29397, 39570, 33479, 34731]
,
    
    "First Name": ["Liam", "Noah", "Oliver", "James", "Elijah", "William", "Henry", "Lucas", "Benjamin", "Theodore", 
                     "Mateo", "Levi", "Sebastian", "Daniel", "Jack", "Michael", "Alexander", "Owen", "Asher", "Samuel", 
                     "Ethan", "Leo", "Jackson", "Mason", "Ezra", "John", "Hudson", "Luca", "Aiden", "Joseph", "David", 
                     "Jacob", "Logan", "Luke", "Julian", "Gabriel", "Grayson", "Wyatt", "Matthew", "Maverick", "Dylan", 
                     "Isaac", "Elias", "Anthony", "Thomas", "Jayden", "Carter", "Santiago", "Ezekiel", "Charles", "Josiah", 
                     "Caleb", "Cooper", "Lincoln", "Miles", "Christopher", "Nathan", "Isaiah", "Kai", "Joshua", "Andrew",
                     "Angel", "Adrian", "Cameron", "Nolan", "Waylon", "Jaxon", "Roman", "Eli", "Wesley", "Aaron", "Ian", 
                     "Christian", "Ryan", "Leonardo", "Brooks", "Axel", "Walker", "Jonathan", "Easton", "Everett", "Weston", 
                     "Bennett", "Robert", "Jameson", "Landon", "Silas", "Jose", "Beau", "Micah"],
        
    "Last Name" : [
                    "Smith", "Johnson", "Williams", "Brown", "Jones", "Garcia", "Miller", "Davis", "Rodriguez", "Martinez",
                    "Hernandez", "Lopez", "Gonzalez", "Wilson", "Anderson", "Thomas", "Taylor", "Moore", "Jackson", "Martin",
                    "Lee", "Perez", "Thompson", "White", "Harris", "Sanchez", "Clark", "Ramirez", "Lewis", "Robinson",
                    "Walker", "Young", "Allen", "King", "Wright", "Scott", "Torres", "Nguyen", "Hill", "Flores", "Green",
                    "Adams", "Nelson", "Baker", "Hall", "Rivera", "Campbell", "Mitchell", "Carter", "Roberts","Khan", "Williams", 
                    "Brown", "Jones", "Garcia", "Miller", "Davis", "Rodriguez", "Martinez","Hernandez", "Lopez", "Gonzalez", "Wilson", 
                    "Anderson", "Thomas", "Taylor", "Moore", "Jackson", "Martin","Lee", "Perez", "Thompson", "White", "Harris",
                    "Sanchez", "Clark", "Ramirez","White", "Harris", "Sanchez", "Clark","Ramirez", "Lewis", "Robinson",
                    "Walker", "Young", "Allen", "King", "Wright", "Scott"],
        
    "Class" : ['12th A', '12th B', '12th B', '12th A', '12th A', '12th C', '12th A', '12th B', '12th A', '12th B', 
               '12th A', '12th A', '12th A', '12th A', '12th B', '12th B', '12th C', '12th B', '12th B', '12th C', 
               '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th C', '12th B', '12th A', '12th A',
               '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th A', '12th C', '12th A', '12th C',
               '12th A', '12th B', '12th C', '12th A', '12th A', '12th B', '12th A', '12th B', '12th A', '12th A', 
               '12th A', '12th A', '12th C', '12th A', '12th C', '12th A', '12th B', '12th A', '12th C', '12th C', 
               '12th B', '12th A', '12th B', '12th A', '12th B', '12th B', '12th B', '12th C', '12th C', '12th B', 
               '12th A', '12th B', '12th B', '12th A', '12th A', '12th B', '12th B', '12th C', '12th C', '12th B', 
               '12th B', '12th B', '12th C', '12th B', '12th C', '12th A', '12th A', '12th A', '12th A', '12th C'],
        
    "Stream": ['Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing',
               'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + Marketing',
               'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + Marketing',
               'Commerce + Math', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + IP', 'Commerce + Math', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + Math', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Math',
               'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + Math', 'Commerce + IP', 'Commerce + IP', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Math'],
  
    
    "Marks": [94, 89, 76, 89, 35, 65, 40, 80, 80, 86, 44, 93, 46, 64, 29, 80, 70, 55, 70, 77, 37, 100, 57, 62, 28,
              29, 47, 25, 86, 98, 51, 99, 30, 58, 54, 94, 53, 36, 100, 49, 21, 86, 64, 38, 43, 68, 29, 85, 84, 76, 
              70, 88, 39, 84, 48, 97, 84, 90, 99, 61, 68, 97, 39, 92, 23, 49, 63, 59, 38, 87, 62, 48, 59, 70, 81, 21,
              89, 30, 100, 59, 62, 63, 57, 77, 46, 54, 93, 41, 77, 89],
    
    "Attendance" :[99, 87, 100, 75, 69, 64, 65, 94, 77, 100, 93, 74, 97, 99, 83, 81, 74, 77, 63, 69, 90, 66, 81, 69, 66, 90,
                   62, 61, 80, 75, 99, 76, 89, 82, 81, 92, 87, 67, 69, 77, 66, 82, 90, 98, 84, 66, 100, 78, 86, 97, 79, 86, 
                   94, 96, 69, 69, 99, 83, 67, 90, 72, 82, 90, 98, 67, 85, 72, 64, 90, 95, 89, 79, 80, 78, 62, 81, 82, 72,
                   70, 77, 82, 69, 60, 71, 79, 91, 69, 85, 66, 63],

    "Date of Birth": ['2006-08-05', '2005-10-03', '2006-02-17', '2007-05-17', '2006-08-05', '2005-10-16',
                      '2007-05-28', '2007-12-13', '2006-10-17', '2005-03-07', '2005-11-27', '2007-12-28',
                      '2006-12-27', '2006-02-19', '2007-03-31', '2006-07-31', '2005-10-14', '2007-11-02',
                      '2007-12-03', '2006-03-02', '2007-02-12', '2007-01-25', '2006-01-07', '2006-01-28',
                      '2006-03-03', '2007-12-08', '2005-09-29', '2005-02-02', '2005-10-16', '2006-03-04', '2005-07-02', 
                      '2006-07-21', '2005-09-10', '2006-05-23', '2005-12-26', '2007-09-19', '2005-06-21', '2005-06-10',
                      '2006-03-12', '2006-03-02', '2007-09-23', '2007-05-11', '2005-01-10', '2007-04-07', '2005-01-06', 
                      '2005-05-10', '2005-07-22', '2006-01-27', '2006-05-10', '2005-03-21', '2005-08-11', '2007-12-12', 
                      '2007-01-10', '2007-04-27', '2005-03-19', '2007-02-06', '2005-12-11', '2006-05-31', '2006-12-18', 
                      '2005-01-20', '2005-12-11', '2005-12-08', '2005-01-02', '2005-06-12', '2007-01-16', '2006-07-10',
                      '2006-07-04', '2006-07-07', '2007-01-29', '2006-11-17', '2006-08-26', '2007-07-02', '2005-05-19', 
                      '2007-05-28', '2007-03-09', '2005-12-14', '2005-09-09', '2006-09-03', '2007-05-12', '2006-07-18',
                      '2006-11-11', '2007-07-27', '2005-03-15', '2007-12-30', '2006-02-19', '2005-03-13', '2005-01-21',
                      '2006-02-24', '2005-09-09', '2005-08-27'],
    
    
    "Transport":['Private', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Bus',
                 'Private', 'Private', 'Private', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Private', 'Private',
                 'Private', 'Bus', 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Bus', 'Private', 'Bus', 'Private', 
                 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Private', 'Private', 'Private', 'Private',
                 'Bus', 'Bus', 'Bus', 'Private', 'Private', 'Private', 'Private', 'Bus', 'Bus', 'Bus', 'Private', 
                 'Bus', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Bus',
                 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Private', 'Private', 'Bus', 'Private', 'Bus',
                 'Private', 'Private', 'Private', 'Bus', 'Bus', 'Bus', 'Private', 'Bus', 'Private', 'Private', 'Bus',
                 'Private', 'Bus', 'Bus', 'Private'],
    
    "Phone Number":['+973 67445631', '+973 60882794', '+973 35703278', '+973 59104319', '+973 78887782', '+973 81443190',
                    '+973 91281124', '+973 47364816', '+973 37742717', '+973 67328349', '+973 75199860', '+973 95905898',
                    '+973 67866050', '+973 92548358', '+973 43782118', '+973 78612719', '+973 83695201', '+973 76361961',
                    '+973 62648332', '+973 82240110', '+973 88479604', '+973 36874375', '+973 47401705', '+973 88355020',
                    '+973 92089214', '+973 69310618', '+973 69231054', '+973 85024799', '+973 79982288', '+973 97702950',
                    '+973 46629239', '+973 81315454', '+973 73393237', '+973 56620392', '+973 37119292', '+973 75522130',
                    '+973 34286111', '+973 42787875', '+973 61821723', '+973 59719946', '+973 79951890', '+973 90250261',
                    '+973 69175570', '+973 39963217', '+973 98173015', '+973 83967714', '+973 63356211', '+973 89000653',
                    '+973 45742242', '+973 61828549', '+973 61308684', '+973 37847996', '+973 39077184', '+973 46808168',
                    '+973 33983329', '+973 66204703', '+973 74507339', '+973 94399739', '+973 45204743', '+973 81175950',
                    '+973 44086024', '+973 62495314', '+973 81368171', '+973 47598358', '+973 95311746', '+973 92118339', 
                    '+973 92796415', '+973 52275477', '+973 33630536', '+973 42792818', '+973 71554561', '+973 58571471', '+973 98785180', '+973 93372201', '+973 81632536', '+973 63942941', '+973 43012849', '+973 44270692', '+973 75180740', '+973 97335181', '+973 74769400', '+973 61972845', '+973 91810611', '+973 34128058', '+973 68629426', '+973 67194302', '+973 75463778', '+973 75614941', '+973 52201014', '+973 86118852']
}
    
df=pd.DataFrame(data)

df.to_csv("Daniya1.csv",index=False)
df.to_excel("Daniya21211.xlsx",index=False)

# %%
fisrt = ["Liam", "Noah", "Oliver", "James", "Elijah", "William", "Henry", "Lucas", "Benjamin", "Theodore","Mateo", "Levi", "Sebastian", "Daniel", "Jack", "Michael", "Alexander", "Owen", "Asher", "Samuel", 
                     "Ethan", "Leo", "Jackson", "Mason", "Ezra", "John", "Hudson", "Luca", "Aiden", "Joseph", "David", 
                     "Jacob", "Logan", "Luke", "Julian", "Gabriel", "Grayson", "Wyatt", "Matthew", "Maverick", "Dylan", 
                     "Isaac", "Elias", "Anthony", "Thomas", "Jayden", "Carter", "Santiago", "Ezekiel", "Charles", "Josiah", 
                     "Caleb", "Cooper", "Lincoln", "Miles", "Christopher", "Nathan", "Isaiah", "Kai", "Joshua", "Andrew",
                     "Angel", "Adrian", "Cameron", "Nolan", "Waylon", "Jaxon", "Roman", "Eli", "Wesley", "Aaron", "Ian", 
                     "Christian", "Ryan", "Leonardo", "Brooks", "Axel", "Walker", "Jonathan", "Easton", "Everett", "Weston", 
                     "Bennett", "Robert", "Jameson", "Landon", "Silas", "Jose", "Beau", "Micah"]
LastName= ["Smith", "Johnson", "Williams", "Brown", "Jones", "Garcia", "Miller", "Davis", "Rodriguez", "Martinez",
                    "Hernandez", "Lopez", "Gonzalez", "Wilson", "Anderson", "Thomas", "Taylor", "Moore", "Jackson", "Martin",
                    "Lee", "Perez", "Thompson", "White", "Harris", "Sanchez", "Clark", "Ramirez", "Lewis", "Robinson",
                    "Walker", "Young", "Allen", "King", "Wright", "Scott", "Torres", "Nguyen", "Hill", "Flores", "Green",
                    "Adams", "Nelson", "Baker", "Hall", "Rivera", "Campbell", "Mitchell", "Carter", "Roberts","Khan", "Williams", 
                    "Brown", "Jones", "Garcia", "Miller", "Davis", "Rodriguez", "Martinez","Hernandez", "Lopez", "Gonzalez", "Wilson", 
                    "Anderson", "Thomas", "Taylor", "Moore", "Jackson", "Martin","Lee", "Perez", "Thompson", "White", "Harris",
                    "Sanchez", "Clark", "Ramirez","White", "Harris", "Sanchez", "Clark","Ramirez", "Lewis", "Robinson",
                    "Walker", "Young", "Allen", "King", "Wright", "Scott"]

# %%
# df=pd.read_csv('Daniya.csv')

import pandas as pd

df= pd.read_excel("Daniya21211.xlsx")
df
# Out:
#     GR Number First Name Last Name   Class                Stream  Marks  \
# 0       25123       Liam     Smith  12th A         Commerce + IP     94
# 1       40653       Noah   Johnson  12th B  Commerce + Marketing     89
# 2       40486     Oliver  Williams  12th B  Commerce + Marketing     76
# 3       42657      James     Brown  12th A         Commerce + IP     89
# 4       24548     Elijah     Jones  12th A         Commerce + IP     35
# ..        ...        ...       ...     ...                   ...    ...
# 85      34679     Landon     Young  12th A         Commerce + IP     54
# 86      29397      Silas     Allen  12th A         Commerce + IP     93
# 87      39570       Jose      King  12th A         Commerce + IP     41
# 88      33479       Beau    Wright  12th A         Commerce + IP     77
# 89      34731      Micah     Scott  12th C       Commerce + Math     89
#
#     Attendance Date of Birth Transport   Phone Number
# ...

# %%
import pandas as pd


data = {
    "GR Number": [25123, 40653, 40486, 42657, 24548, 32820, 45824, 25810, 40497, 40941, 25086, 42181, 30114, 25107, 37161,
                  34173, 37307, 40667, 30962, 41859, 38720, 22481, 34033, 46709, 43706, 44003, 30524, 39668, 29420, 24923,
                  36697, 22368, 53030, 26760, 55118, 22607, 53917, 40509, 25899, 39133, 38273, 47985, 43201, 22701, 36944, 
                  53926, 48103, 42850, 38400, 34087, 42474, 39733, 41636, 46723, 47535, 36946, 35548, 31500, 30523, 30872,
                  48563, 41371, 27073, 42182, 45001, 54947, 47641, 47854, 30751, 37940, 50861, 33637, 34689, 39646, 54790, 
                  38058, 30553, 27155, 37237, 43835, 43244, 48961, 39995, 38851, 55241, 34679, 29397, 39570, 33479, 34731]
,
    
    "Student Name" : ['Liam Smith', 'Noah Johnson', 'Oliver Williams', 'James Brown', 'Elijah Jones', 'William Garcia',
                      'Henry Miller', 'Lucas Davis', 'Benjamin Rodriguez', 'Theodore Martinez', 'Mateo Hernandez',
                      
                      'Levi Lopez', 'Sebastian Gonzalez', 'Daniel Wilson', 'Jack Anderson', 'Michael Thomas',
                      'Alexander Taylor', 'Owen Moore', 'Asher Jackson', 'Samuel Martin', 'Ethan Lee', 'Leo Perez',
                      'Jackson Thompson', 'Mason White', 'Ezra Harris', 'John Sanchez', 'Hudson Clark', 'Luca Ramirez',
                      'Aiden Lewis', 'Joseph Robinson', 'David Walker', 'Jacob Young', 'Logan Allen', 'Luke King',
                      'Julian Wright', 'Gabriel Scott', 'Grayson Torres', 'Wyatt Nguyen', 'Matthew Hill', 'Maverick Flores', 
                      'Dylan Green', 'Isaac Adams', 'Elias Nelson', 'Anthony Baker', 'Thomas Hall', 'Jayden Rivera',
                      'Carter Campbell', 'Santiago Mitchell', 'Ezekiel Carter', 'Charles Roberts', 'Josiah Khan', 
                      
                      'Caleb Williams', 'Cooper Brown', 'Lincoln Jones', 'Miles Garcia', 'Christopher Miller', 
                      'Nathan Davis', 'Isaiah Rodriguez', 'Kai Martinez', 'Joshua Hernandez', 'Andrew Lopez', 
                      'Angel Gonzalez', 'Adrian Wilson', 'Cameron Anderson', 'Nolan Thomas', 'Waylon Taylor',
                      'Jaxon Moore', 'Roman Jackson', 'Eli Martin', 'Wesley Lee', 'Aaron Perez', 'Ian Thompson', 
                      'Christian White', 'Ryan Harris', 'Leonardo Sanchez', 'Brooks Clark', 'Axel Ramirez', 
                      'Walker White', 'Jonathan Harris', 'Easton Sanchez', 'Everett Clark', 'Weston Ramirez',
                      'Bennett Lewis', 'Robert Robinson', 'Jameson Walker', 'Landon Young', 'Silas Allen', 
                      'Jose King', 'Beau Wright', 'Micah Scott']
 ,
    "Result" : [
                    'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS',
    'PASS', 'PASS', 'PASS', 'FAIL', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS',
    'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS',
    'PASS', 'FAIL', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'FAIL',
    'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS', 'PASS',
    'FAIL', 'PASS', 'PASS', 'FAIL', 'PASS', 'FAIL', 'PASS', 'PASS'
],

        
    "Class" : ['12th A', '12th B', '12th B', '12th A', '12th A', '12th C', '12th A', '12th B', '12th A', '12th B', 
               '12th A', '12th A', '12th A', '12th A', '12th B', '12th B', '12th C', '12th B', '12th B', '12th C', 
               '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th C', '12th B', '12th A', '12th A',
               '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th A', '12th C', '12th A', '12th C',
               '12th A', '12th B', '12th C', '12th A', '12th A', '12th B', '12th A', '12th B', '12th A', '12th A', 
               '12th A', '12th A', '12th C', '12th A', '12th C', '12th A', '12th B', '12th A', '12th C', '12th C', 
               '12th B', '12th A', '12th B', '12th A', '12th B', '12th B', '12th B', '12th C', '12th C', '12th B', 
               '12th A', '12th B', '12th B', '12th A', '12th A', '12th B', '12th B', '12th C', '12th C', '12th B', 
               '12th B', '12th B', '12th C', '12th B', '12th C', '12th A', '12th A', '12th A', '12th A', '12th C'],
        
    "Stream": ['Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing',
               'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + Marketing',
               'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + Marketing',
               'Commerce + Math', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + IP', 'Commerce + Math', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + IP', 'Commerce + IP', 'Commerce + Math', 'Commerce + IP',
               'Commerce + Math', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Math',
               'Commerce + Math', 'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Marketing', 'Commerce + Math',
               'Commerce + Marketing', 'Commerce + Math', 'Commerce + IP', 'Commerce + IP', 'Commerce + IP',
               'Commerce + IP', 'Commerce + Math'],
  
    
    "Marks": [94, 89, 76, 89, 35, 65, 40, 80, 80, 86, 44, 93, 46, 64, 29, 80, 70, 55, 70, 77, 37, 100, 57, 62, 28,
              29, 47, 25, 86, 98, 51, 99, 30, 58, 54, 94, 53, 36, 100, 49, 21, 86, 64, 38, 43, 68, 29, 85, 84, 76, 
              70, 88, 39, 84, 48, 97, 84, 90, 99, 61, 68, 97, 39, 92, 23, 49, 63, 59, 38, 87, 62, 48, 59, 70, 81, 21,
              89, 30, 100, 59, 62, 63, 57, 77, 46, 54, 93, 41, 77, 89],
    
    "Attendance" :[99, 87, 100, 75, 69, 64, 65, 94, 77, 100, 93, 74, 97, 99, 83, 81, 74, 77, 63, 69, 90, 66, 81, 69, 66, 90,
                   62, 61, 80, 75, 99, 76, 89, 82, 81, 92, 87, 67, 69, 77, 66, 82, 90, 98, 84, 66, 100, 78, 86, 97, 79, 86, 
                   94, 96, 69, 69, 99, 83, 67, 90, 72, 82, 90, 98, 67, 85, 72, 64, 90, 95, 89, 79, 80, 78, 62, 81, 82, 72,
                   70, 77, 82, 69, 60, 71, 79, 91, 69, 85, 66, 63],

    "Date of Birth": ['2006-08-05', '2005-10-03', '2006-02-17', '2007-05-17', '2006-08-05', '2005-10-16',
                      '2007-05-28', '2007-12-13', '2006-10-17', '2005-03-07', '2005-11-27', '2007-12-28',
                      '2006-12-27', '2006-02-19', '2007-03-31', '2006-07-31', '2005-10-14', '2007-11-02',
                      '2007-12-03', '2006-03-02', '2007-02-12', '2007-01-25', '2006-01-07', '2006-01-28',
                      '2006-03-03', '2007-12-08', '2005-09-29', '2005-02-02', '2005-10-16', '2006-03-04', '2005-07-02', 
                      '2006-07-21', '2005-09-10', '2006-05-23', '2005-12-26', '2007-09-19', '2005-06-21', '2005-06-10',
                      '2006-03-12', '2006-03-02', '2007-09-23', '2007-05-11', '2005-01-10', '2007-04-07', '2005-01-06', 
                      '2005-05-10', '2005-07-22', '2006-01-27', '2006-05-10', '2005-03-21', '2005-08-11', '2007-12-12', 
                      '2007-01-10', '2007-04-27', '2005-03-19', '2007-02-06', '2005-12-11', '2006-05-31', '2006-12-18', 
                      '2005-01-20', '2005-12-11', '2005-12-08', '2005-01-02', '2005-06-12', '2007-01-16', '2006-07-10',
                      '2006-07-04', '2006-07-07', '2007-01-29', '2006-11-17', '2006-08-26', '2007-07-02', '2005-05-19', 
                      '2007-05-28', '2007-03-09', '2005-12-14', '2005-09-09', '2006-09-03', '2007-05-12', '2006-07-18',
                      '2006-11-11', '2007-07-27', '2005-03-15', '2007-12-30', '2006-02-19', '2005-03-13', '2005-01-21',
                      '2006-02-24', '2005-09-09', '2005-08-27'],
    
    
    "Transport":['Private', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Bus',
                 'Private', 'Private', 'Private', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Private', 'Private',
                 'Private', 'Bus', 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Bus', 'Private', 'Bus', 'Private', 
                 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Private', 'Private', 'Private', 'Private',
                 'Bus', 'Bus', 'Bus', 'Private', 'Private', 'Private', 'Private', 'Bus', 'Bus', 'Bus', 'Private', 
                 'Bus', 'Private', 'Bus', 'Private', 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Bus',
                 'Bus', 'Bus', 'Private', 'Private', 'Bus', 'Private', 'Private', 'Private', 'Bus', 'Private', 'Bus',
                 'Private', 'Private', 'Private', 'Bus', 'Bus', 'Bus', 'Private', 'Bus', 'Private', 'Private', 'Bus',
                 'Private', 'Bus', 'Bus', 'Private'],
    
    "Phone Number":['+973 67445631', '+973 60882794', '+973 35703278', '+973 59104319', '+973 78887782', '+973 81443190',
                    '+973 91281124', '+973 47364816', '+973 37742717', '+973 67328349', '+973 75199860', '+973 95905898',
                    '+973 67866050', '+973 92548358', '+973 43782118', '+973 78612719', '+973 83695201', '+973 76361961',
                    '+973 62648332', '+973 82240110', '+973 88479604', '+973 36874375', '+973 47401705', '+973 88355020',
                    '+973 92089214', '+973 69310618', '+973 69231054', '+973 85024799', '+973 79982288', '+973 97702950',
                    '+973 46629239', '+973 81315454', '+973 73393237', '+973 56620392', '+973 37119292', '+973 75522130',
                    '+973 34286111', '+973 42787875', '+973 61821723', '+973 59719946', '+973 79951890', '+973 90250261',
                    '+973 69175570', '+973 39963217', '+973 98173015', '+973 83967714', '+973 63356211', '+973 89000653',
                    '+973 45742242', '+973 61828549', '+973 61308684', '+973 37847996', '+973 39077184', '+973 46808168',
                    '+973 33983329', '+973 66204703', '+973 74507339', '+973 94399739', '+973 45204743', '+973 81175950',
                    '+973 44086024', '+973 62495314', '+973 81368171', '+973 47598358', '+973 95311746', '+973 92118339', 
                    '+973 92796415', '+973 52275477', '+973 33630536', '+973 42792818', '+973 71554561', '+973 58571471', '+973 98785180', '+973 93372201', '+973 81632536', '+973 63942941', '+973 43012849', '+973 44270692', '+973 75180740', '+973 97335181', '+973 74769400', '+973 61972845', '+973 91810611', '+973 34128058', '+973 68629426', '+973 67194302', '+973 75463778', '+973 75614941', '+973 52201014', '+973 86118852']
}
    
df=pd.DataFrame(data)

df.to_csv("Daniya1.csv",index=False)
df.to_excel("Daniya2323.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 124
#       1 import pandas as pd
#       4 data = {
#       5     "GR Number": [25123, 40653, 40486, 42657, 24548, 32820, 45824, 25810, 40497, 40941, 25086, 42181, 30114, 25107, 37161,
#       6                   34173, 37307, 40667, 30962, 41859, 38720, 22481, 34033, 46709, 43706, 44003, 30524, 39668, 29420, 24923,
#    (...)
#     121                     '+973 92796415', '+973 52275477', '+973 33630536', '+973 42792818', '+973 71554561', '+973 58571471', '+973 98785180', '+973 93372201', '+973 81632536', '+973 63942941', '+973 43012849', '+973 44270692', '+973 75180740', '+973 97335181', '+973 74769400', '+973 61972845', '+973 91810611', '+973 34128058', '+973 68629426', '+973 67194302', '+973 75463778', '+973 75614941', '+973 52201014', '+973 86118852']
#     122 }
# --> 124 df=pd.DataFrame(data)
# ...

# %%
len(df["Student Name"])
# Out:
# 90

# %%
def first(df): 
    df1=df.to_string()
    print(df1)
    
def display(df):
    if 0<records<91 or n==2 or n==3:
        if n==1:
            print(f"Top {records} Students list")
            print(df.head(records))
        else :
            print(f"Bottom {n} Students list")
            print(df.tail(records))
    else:
        print("Invalid input")

# %%
# Date of birth

from datetime import datetime, timedelta
import random
start = datetime(2005,1,1)
end = datetime(2007,12,31)

l=[]
for  _ in range(90):
    data= start+timedelta(days=random.randint(0,(end-start).days))
    l.append(data.strftime("%Y-%m-%d"))
    
    
# Phone number


phone =set()
while len(phone)<90:
    phone.add("+973 " +str(random.randint(33333333,99999999)))
phone_l=list(phone)

print(phone_l)


#attendance
# Out:
# ['+973 92452541', '+973 94596220', '+973 51538949', '+973 92285740', '+973 36486368', '+973 97960699', '+973 44777303', '+973 38403847', '+973 72308083', '+973 47721754', '+973 43685084', '+973 60686279', '+973 63092017', '+973 91323047', '+973 82032261', '+973 45995570', '+973 69290578', '+973 63864954', '+973 46134696', '+973 42699631', '+973 87699994', '+973 99224266', '+973 67142224', '+973 94856843', '+973 64005447', '+973 72977875', '+973 61228614', '+973 99257403', '+973 65221192', '+973 44983460', '+973 42169115', '+973 52385681', '+973 76072118', '+973 38946605', '+973 49006363', '+973 69908885', '+973 65308398', '+973 58539754', '+973 67800010', '+973 41853732', '+973 98323157', '+973 90299595', '+973 88512335', '+973 99175298', '+973 44742344', '+973 72168835', '+973 86497307', '+973 76577790', '+973 49717373', '+973 51676181', '+973 38571056', '+973 44583176', '+973 63786693', '+973 63624743', '+973 34208645', '+973 73023546', '+973 50388796', '+973 72262622', '+973 36907
# ...

# %%
print("1 to show Top n records or Bottom n records")
print("2 to show perticular student report ")
print("3 to add record")
print("5 to delet record")

a=int(input())

if a==1 :
    b=int(input("1 for top /n 2 for bottom : "))
    c=int(input("how many records : "))
    print("  ------------------   ")
    
    display(df,b,c)
# Out:
# 1 to show Top n records or Bottom n records
# 2 to show perticular student report
# 3 to add record
# 5 to delet record
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 print("3 to add record")
#       4 print("5 to delet record")
# ----> 6 a=int(input())
#       8 if a==1 :
#       9     b=int(input("1 for top /n 2 for bottom : "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# a=input("Enter the name : ")
# df[df["First Name"]==a]

def a(row):
    if row["Stream"]=="Commerce + IP":
        return "12th A"
    if row["Stream"] == "Commerce + Marketing":
        return "12th B"
    if row["Stream"] == "Commerce + Math":
        return "12th C"
    
df["Class"]= df.apply(a,axis=1)
df["Class"].value_counts()
print(list(df['Class']))
# Out:
# ['12th A', '12th B', '12th B', '12th A', '12th A', '12th C', '12th A', '12th B', '12th A', '12th B', '12th A', '12th A', '12th A', '12th A', '12th B', '12th B', '12th C', '12th B', '12th B', '12th C', '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th C', '12th B', '12th A', '12th A', '12th B', '12th C', '12th B', '12th A', '12th B', '12th A', '12th A', '12th C', '12th A', '12th C', '12th A', '12th B', '12th C', '12th A', '12th A', '12th B', '12th A', '12th B', '12th A', '12th A', '12th A', '12th A', '12th C', '12th A', '12th C', '12th A', '12th B', '12th A', '12th C', '12th C', '12th B', '12th A', '12th B', '12th A', '12th B', '12th B', '12th B', '12th C', '12th C', '12th B', '12th A', '12th B', '12th B', '12th A', '12th A', '12th B', '12th B', '12th C', '12th C', '12th B', '12th B', '12th B', '12th C', '12th B', '12th C', '12th A', '12th A', '12th A', '12th A', '12th C']

# %%
new=input("Enter the information required : ")
if new=="Stream":
    print(df[["First Name","Stream"]])
elif new == "Transport" :
    print(df[df["First Name"]==a][""]["Transport"])
else:
    print("Invaild")
# Out:
# Enter the information required : w
# Invaild

# %%
df
# Out:
#     GR Number First Name Last Name   Class                Stream  Marks  \
# 0       25123       Liam     Smith  12th A         Commerce + IP     94
# 1       40653       Noah   Johnson  12th B  Commerce + Marketing     89
# 2       40486     Daniya    Saiyed  12th A         Commerce + IP     96
# 3       42657      James     Brown  12th A         Commerce + IP     89
# 4       24548     Elijah     Jones  12th A         Commerce + IP     35
# ..        ...        ...       ...     ...                   ...    ...
# 85      34679     Landon     Young  12th A         Commerce + IP     54
# 86      29397      Silas     Allen  12th A         Commerce + IP     93
# 87      39570       Jose      King  12th A         Commerce + IP     41
# 88      33479       Beau    Wright  12th A         Commerce + IP     77
# 89      34731      Micah     Scott  12th C       Commerce + Math     89
#
#     Attendance Date of Birth Transport   Phone Number
# ...

# %%
import matplotlib.pyplot as plt

def plots(df):
    
    plt.bar(df["Stream"], df['Marks'])
    plt.xlabel('Student Names')
    plt.ylabel('Marks')
    plt.title('Marks Obtained by Students')

    plt.tight_layout()

    plt.show()

# %%
plots(df)

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Attendance'], edgecolor='black')
plt.xlabel('Attendance')
plt.ylabel('Frequency')
plt.title('Distribution of Attendance')

plt.show()

# %%
df
# Out:
#     GR Number First Name Last Name   Class                Stream  Marks  \
# 0       25123       Liam     Smith  12th A         Commerce + IP     94
# 1       40653       Noah   Johnson  12th B  Commerce + Marketing     89
# 2       40486     Daniya    Saiyed  12th A         Commerce + IP     96
# 3       42657      James     Brown  12th A         Commerce + IP     89
# 4       24548     Elijah     Jones  12th A         Commerce + IP     35
# ..        ...        ...       ...     ...                   ...    ...
# 85      34679     Landon     Young  12th A         Commerce + IP     54
# 86      29397      Silas     Allen  12th A         Commerce + IP     93
# 87      39570       Jose      King  12th A         Commerce + IP     41
# 88      33479       Beau    Wright  12th A         Commerce + IP     77
# 89      34731      Micah     Scott  12th C       Commerce + Math     89
#
#     Attendance Date of Birth Transport   Phone Number
# ...

# %%
streams = list(df['Stream'])
stream_marks = [df['Marks'][df['Stream'] == stream].mean() for stream in streams]

plt.figure(figsize=(10, 6))
plt.bar(streams, stream_marks, color='#5fbdff',edgecolor='black')
plt.xlabel('Stream')
plt.ylabel('Average Marks')
plt.title('Average Marks by Stream')
plt.tight_layout()
plt.show()

# %%
print(stream_marks)
# Out:
# [69.6842105263158, 59.40625, 69.6842105263158, 69.6842105263158, 69.6842105263158, 63.65, 69.6842105263158, 59.40625, 69.6842105263158, 59.40625, 69.6842105263158, 69.6842105263158, 69.6842105263158, 69.6842105263158, 59.40625, 59.40625, 63.65, 59.40625, 59.40625, 63.65, 59.40625, 63.65, 59.40625, 69.6842105263158, 59.40625, 69.6842105263158, 63.65, 59.40625, 69.6842105263158, 69.6842105263158, 59.40625, 63.65, 59.40625, 69.6842105263158, 59.40625, 69.6842105263158, 69.6842105263158, 63.65, 69.6842105263158, 63.65, 69.6842105263158, 59.40625, 63.65, 69.6842105263158, 69.6842105263158, 59.40625, 69.6842105263158, 59.40625, 69.6842105263158, 69.6842105263158, 69.6842105263158, 69.6842105263158, 63.65, 69.6842105263158, 63.65, 69.6842105263158, 59.40625, 69.6842105263158, 63.65, 63.65, 59.40625, 69.6842105263158, 59.40625, 69.6842105263158, 59.40625, 59.40625, 59.40625, 63.65, 63.65, 59.40625, 69.6842105263158, 59.40625, 59.40625, 69.6842105263158, 69.6842105263158, 59.40625, 59.40625, 
# ...

# %%
# funciton 

def first(df):
    pd
